# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import argrelextrema

# %%
def get_stock_data(ticker,start_date='2014-01-29', interval='1d', period='2y'):
    """
    Fetch historical stock data.
        ticker: name of the fund
        interval: time interval for fetching data ('1d', '1h', '1m', etc.)
        period: period to fetch data for ('1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max')
    """
    stock = yf.Ticker(ticker)
    data = stock.history(start=start_date, interval=interval, period=period)
    if not isinstance(data, pd.DataFrame) or data.empty:
        raise ValueError(f"No valid data found for ticker {ticker}.")
    return data

# %%
def find_extrema(data, column='Close', order=5):
    """
    Find local and global extrema of stock prices.
    """
    prices = data[column]
    
    # Local minima and maxima using argrelextrema
    local_maxima = argrelextrema(prices.values, np.greater, order=order)[0]
    local_minima = argrelextrema(prices.values, np.less, order=order)[0]

    # Global extrema (max and min)
    global_max = prices.idxmax()  # Date of global maximum
    global_min = prices.idxmin()  # Date of global minimum

    # Return results with corresponding dates and values
    return {
        'local_maxima': data.iloc[local_maxima],  # Local maxima with dates and prices
        'local_minima': data.iloc[local_minima],  # Local minima with dates and prices
        'global_max': (global_max, prices[global_max]),  # Global maximum date and price
        'global_min': (global_min, prices[global_min])   # Global minimum date and price
    }

# %%
def analyze_stocks(tickers, interval='1d', period='2y', order=5,start_date='2017-01-01'):
    extrema_data = []
    for ticker in tickers:
        print(f"Fetching data for {ticker}...")
        try:
            data = get_stock_data(ticker, interval=interval, period=period, start_date=start_date)
            data.reset_index(inplace=True)  # Reset index to access 'Date' as a column
            print(f"Data for {ticker} fetched successfully. Columns: {data.columns.tolist()}")
            
            data = data[['Date', 'Close']]  # Extract 'Date' and 'Close' columns
            data.columns = ['date', 'price']  # Rename columns for consistency
            
            extrema = find_extrema(data, column='price', order=order)

            # Add local extrema to the result list
            extrema_data.extend([{
                'date': row['date'], 'type': 'local_minima', 'ticker': ticker, 'price': row['price']
            } for _, row in extrema['local_minima'].iterrows()])
            extrema_data.extend([{
                'date': row['date'], 'type': 'local_maxima', 'ticker': ticker, 'price': row['price']
            } for _, row in extrema['local_maxima'].iterrows()])

            # Find and add global extrema
            global_max = data.loc[data['price'].idxmax()]
            global_min = data.loc[data['price'].idxmin()]
            extrema_data.append({
                'date': global_max['date'], 'type': 'global_max', 'ticker': ticker, 'price': global_max['price']
            })
            extrema_data.append({
                'date': global_min['date'], 'type': 'global_min', 'ticker': ticker, 'price': global_min['price']
            })

        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

    # Convert to DataFrame and save to CSV
    if extrema_data:
        extrema_df = pd.DataFrame(extrema_data)
        extrema_df.to_csv('extrema_dates.csv', index=False)
        print("Extrema data saved to 'extrema_dates.csv'.")
    else:
        print("No extrema data to save.")

# %%
# Analyze multiple stocks and save extrema dates
tickers = ['AAPL', 'MSFT', 'GOOGL', 'TSLA', 'NVDA', 'AMD', 'AMZN', 'NFLX', 'INTC', 'XOM', 'CVX', 'OXY', 'MRNA', 'PFE', 'BIIB', 'GME', 'AMC', 'BB', 'PLUG', 'PLTR', 'ROKU', 'ZM', 'SQ', 'PYPL', 'UBER', 'LYFT', 'T', 'VZ', 'TMUS', 'S', 'TM', 'F', 'GM', 'NIO', 'LI', 'XPEV', 'PBM', 'SRM', 'NTRP', 'ENTO', 'CRKN', 'JZXN', 'ABP']
analyze_stocks(tickers, interval='1d', period='2y', order=5,start_date='2014-01-29')
# Out:
# Fetching data for AAPL...
# Data for AAPL fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for MSFT...
# Data for MSFT fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for GOOGL...
# Data for GOOGL fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for TSLA...
# Data for TSLA fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for NVDA...
# Data for NVDA fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for AMD...
# Data for AMD fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for AMZN...
# Data for AMZN fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for NFLX...
# Data for NFLX fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for INTC...
# Data for INTC fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for XOM...
# Data for XOM fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for CVX...
# Data for CVX fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for OXY...
# Data for OXY fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for MRNA...
# Data for MRNA fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for PFE...
# Data for PFE fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for BIIB...
# Data for BIIB fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for GME...
# Data for GME fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for AMC...
# Data for AMC fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for BB...
# Data for BB fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for PLUG...
# Data for PLUG fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for PLTR...
# Data for PLTR fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for ROKU...
# Data for ROKU fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for ZM...
# Data for ZM fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for SQ...
# Data for SQ fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for PYPL...
# Data for PYPL fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for UBER...
# Data for UBER fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for LYFT...
# Data for LYFT fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for T...
# Data for T fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for VZ...
# Data for VZ fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for TMUS...
# Data for TMUS fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for S...
# Data for S fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for TM...
# Data for TM fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for F...
# Data for F fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for GM...
# Data for GM fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for NIO...
# Data for NIO fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for LI...
# Data for LI fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for XPEV...
# Data for XPEV fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for PBM...
# Data for PBM fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for SRM...
# Data for SRM fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for NTRP...
# Data for NTRP fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for ENTO...
# Data for ENTO fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for CRKN...
# Data for CRKN fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for JZXN...
# Data for JZXN fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Fetching data for ABP...
# Data for ABP fetched successfully. Columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']
# Extrema data saved to 'extrema_dates.csv'.
